# %% [markdown]
# **Descripción del Cuaderno**
#
# Este cuaderno está diseñado para trabajar con modelos de aprendizaje automático utilizando TensorFlow y otras bibliotecas relevantes.
#
# 1. **Instalación y Configuración**: Desinstala versiones anteriores de TensorFlow y `tf-keras` e instala TensorFlow 2.15.0.
#
# 2. **Importación de Librerías**: Incluye `sklearn` para herramientas de machine learning, `tensorflow` y `keras` para aprendizaje profundo, `numpy` para operaciones numéricas, `os` para manejo de archivos, y `matplotlib` para visualización.
#
# 3. **Configuración del Entorno**: Establece semillas para reproducibilidad y configura Matplotlib para mostrar gráficos en línea con tamaños de fuente específicos.
#
# 4. **Configuración de Directorios y Funciones para Guardar Figuras**: Define el directorio para guardar imágenes y funciones para guardar figuras y trazar imágenes.
#
# 5. **Carga y Preprocesamiento de Datos**: Carga el conjunto de datos Fashion MNIST, normaliza los valores de los píxeles y divide el conjunto de entrenamiento en datos de entrenamiento y validación.
#
# 6. **Definición de Métricas y Funciones de Ajuste de Tasa de Aprendizaje**: Incluye una métrica personalizada para precisión redondeada y funciones para ajustar la tasa de aprendizaje.
#
# 7. **Funciones para Visualización de Reconstrucciones**: Visualiza las reconstrucciones generadas por el modelo comparadas con las imágenes originales.
#
# 8. **Evaluación de Modelos**: Evalúa el modelo en el conjunto de prueba y muestra gráficos de pérdida y precisión durante el entrenamiento.
#
# 9. **Definición de Clases y Funciones para Autoencoders Variacionales**: Incluye una función de pérdida escalada y una capa de muestreo para autoencoders variacionales.
#
# 10. **Evaluación Avanzada del Discriminador**: Evalúa el discriminador de un GAN generando imágenes falsas y reales, y calcula métricas de rendimiento como la curva ROC y la matriz de confusión.
#
# 11. **Instalación de Paquetes Adicionales**: Instala paquetes adicionales para la generación de GIFs y documentación de TensorFlow.

# %%
# !pip uninstall -y tensorflow tf-keras
# !pip install tensorflow==2.15.0
# Out:
# Found existing installation: tensorflow 2.17.0
# Uninstalling tensorflow-2.17.0:
#   Successfully uninstalled tensorflow-2.17.0
# Found existing installation: tf_keras 2.17.0
# Uninstalling tf_keras-2.17.0:
#   Successfully uninstalled tf_keras-2.17.0

# %%
import sklearn
import tensorflow as tf
from tensorflow import keras
# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "autoencoders"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")
# Cargar los datos
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalizar los datos
X_train_full = X_train_full.astype(np.float32) / 255.
X_test = X_test.astype(np.float32) / 255.

# Dividir los datos en entrenamiento y validación
X_train, X_valid = X_train_full[:-5000], X_train_full[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]

# Agregar la dimensión del canal
X_train = np.expand_dims(X_train, axis=-1)  # Agrega la dimensión de canal
X_valid = np.expand_dims(X_valid, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))
def piecewise_constant_fn(epoch):
    if epoch < 5:
        return 0.01
    elif epoch < 15:
        return 0.005
    else:
        return 0.001
def piecewise_constant(boundaries, values):
    boundaries = np.array([0] + boundaries)
    values = np.array(values)
    def piecewise_constant_fn(epoch):
        return values[np.argmax(boundaries > epoch) - 1]
    return piecewise_constant_fn
import matplotlib.pyplot as plt
import tensorflow as tf

def evaluar_modelo(history, model, X_test):
    # Evaluar el modelo en los datos de prueba
    resultado = model.evaluate(X_test, X_test, verbose=0)
    print(f'Evaluación con test: Loss= {resultado[0]}, Acc= {resultado[1]}')

    # Crear una figura con dos subplots
    plt.figure(figsize=(12, 5))

    # Subplot 1: Pérdida
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Pérdida durante el entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('Error')
    plt.legend()

    # Subplot 2: Precisión (accuracy)
    if 'rounded_accuracy' in history.history:
        plt.subplot(1, 2, 2)
        plt.plot(history.history['rounded_accuracy'], label='Acc')
        plt.plot(history.history['val_rounded_accuracy'], label='Val Acc')
        plt.title('Precisión durante el entrenamiento')
        plt.xlabel('Épocas')
        plt.ylabel('Acc')
        plt.legend()

    # Mostrar las gráficas
    plt.show()

import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras import backend as K

# Definición de ScaledBinaryCrossentropy y Sampling
class ScaledBinaryCrossentropy(keras.losses.Loss):
    def __init__(self, scale):
        super(ScaledBinaryCrossentropy, self).__init__()
        self.scale = scale

    def call(self, y_true, y_pred):
        return self.scale * tf.keras.losses.mae(y_true, y_pred)

class Sampling(keras.layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
# !pip install tf-keras-vis
from tf_keras_vis.gradcam_plus_plus import GradcamPlusPlus
from tf_keras_vis.utils.model_modifiers import ReplaceToLinear
from tf_keras_vis.utils.scores import CategoricalScore
from tensorflow.keras.models import Model
import numpy as np
import matplotlib.pyplot as plt
tf.random.set_seed(42)
np.random.seed(42)

def plot_cam(layer_name, image, target_class, ax, max_value,min_value, model_for_gradcam, gradcam):
    """
    Genera y plotea el CAM para una imagen dada y una clase objetivo.
    """
    # Ajustar la imagen a la forma correcta si es necesario
    image = image.reshape(1, 28, 28,1)

    # Generar el CAM con GradCAM++ usando la capa especificada
    cam = gradcam(CategoricalScore(target_class), image, penultimate_layer=layer_name, normalize_cam=False)
    avg_intensity = np.mean(cam[0])

    # Plotear la imagen original
    img = ax.imshow(image.squeeze(), cmap='binary')

    # Superponer el CAM como un mapa de calor
    heatmap = ax.imshow(cam[0], cmap='jet',alpha=0.5, vmin=min_value, vmax=max_value)  # Ajustar el rango con vmin y vmax

    # Configuración de la gráfica
    ax.set_title(round(avg_intensity,2))
    ax.axis('off')
    return heatmap

def generate_and_plot_cam_for_output(model, X_test, y_test, layers, output_name, class_mode=True):
    """
    Genera y plotea CAMs para cada capa y salida especificada.

    Args:
        model: Modelo de Keras con el que se generarán los CAMs.
        X_test: Imágenes de prueba.
        y_test: Etiquetas de prueba.
        layers: Lista de nombres de capas para las que se generarán los CAMs.
        output_name: Nombre de la salida que se desea analizar ('classifier', 'reconstruction', 'dkl_loss').
        class_mode: Si es True, generará CAMs para cada clase; si es False, mostrará el valor del CAM para la imagen dada.
    """
    # Configuración para obtener el modelo para GradCAM++
    model_for_gradcam = Model(inputs=model.input, outputs=model.get_layer(output_name).output)
    gradcam = GradcamPlusPlus(model_for_gradcam, model_modifier=ReplaceToLinear(), clone=True)

    # Recorrer cada capa
    for layer in layers:
        print(f'Capa: {layer}')
        for class_label in range(10):
            # Obtener el índice de la primera imagen de la clase actual
            index = np.where(y_test == class_label)[0][0]

            # Configuración de la figura para las 10 clases si estamos en modo clasificación
            if class_mode and output_name == 'classifier':
                fig, axes = plt.subplots(1, 10, figsize=(20, 2))
                # Calcular el valor máximo de los CAMs para esta capa y clase
                cams = [gradcam(CategoricalScore(target_class), X_test[index].reshape(1, 28, 28,1), penultimate_layer=layer, normalize_cam=False)[0] for target_class in range(10)]
                max_value = np.max(cams)
                min_value = np.min(cams)

                # Generar y mostrar los CAMs para cada clase
                heatmaps = []
                for target_class in range(10):
                    ax = axes[target_class]
                    heatmap = plot_cam(layer, X_test[index], target_class, ax, max_value,min_value, model_for_gradcam, gradcam)
                    heatmaps.append(heatmap)

                # Añadir una colorbar común para esta fila de imágenes
                fig.colorbar(heatmaps[0], ax=axes, orientation='vertical', fraction=0.02, pad=0.04)
                plt.show()
            else:
                # Modo para las otras salidas
                fig, ax = plt.subplots(1, 1, figsize=(5, 5))
                cam = gradcam(CategoricalScore(0), X_test[index].reshape(1, 28, 28,1), penultimate_layer=layer, normalize_cam=False)
                avg_intensity = np.mean(cam[0])
                ax.imshow(X_test[index].squeeze(), cmap='binary')
                ax.imshow(cam[0], cmap='jet', alpha=0.5)
                ax.set_title(f'{output_name}, Avg Intensity: {avg_intensity:.2f}')
                ax.axis('off')
                plt.show()
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, fbeta_score, confusion_matrix, classification_report, ConfusionMatrixDisplay, roc_curve, auc

def show_reconstructions(model, images=X_valid, n_images=5):
    """
    Muestra las imágenes originales y sus reconstrucciones generadas por el modelo.

    Parámetros:
    model: El modelo entrenado de autoencoder variacional.
    images: Las imágenes de entrada para generar las reconstrucciones (por defecto, X_valid).
    n_images: Número de imágenes a mostrar.
    """
    # Obtener las reconstrucciones del modelo
    reconstructions = model.predict(images[:n_images])[0]

    # Crear una figura con subplots para mostrar las imágenes
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        # Mostrar imagen original
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        # Mostrar imagen reconstruida
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])

def plot_multiple_images(images, n_cols=None):
    """
    Muestra múltiples imágenes en una cuadrícula.

    Parámetros:
    images: Lista de imágenes a mostrar.
    n_cols: Número de columnas en la cuadrícula. Si es None, se usa el número de imágenes.
    """
    n_cols = n_cols or len(images)
    n_rows = (len(images) - 1) // n_cols + 1

    # Eliminar el canal si es unidimensional
    if images.shape[-1] == 1:
        images = np.squeeze(images, axis=-1)

    plt.figure(figsize=(n_cols, n_rows))
    for index, image in enumerate(images):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(image, cmap="binary")
        plt.axis("off")

def evaluar_modelo(history, model, X_test, y_test, num_classes=10):
    """
    Evalúa el modelo y muestra las métricas y gráficas de desempeño.

    Parámetros:
    history: Historial del entrenamiento del modelo.
    model: El modelo entrenado de autoencoder variacional.
    X_test: Datos de entrada de prueba.
    y_test: Etiquetas de prueba.
    num_classes: Número de clases en la salida de clasificación.
    """
    # Obtener las predicciones del modelo
    y_pred_probs = model.predict(X_test)
    y_pred = np.argmax(y_pred_probs[-1], axis=1)

    # Calcular la precisión de clasificación usando accuracy_score
    accuracy = accuracy_score(np.argmax(y_test,axis=1), y_pred)

    # Evaluar el modelo en los datos de prueba usando model.evaluate
    #resultado = model.evaluate(X_test, {"reconstruction": X_test, "dkl_loss": np.zeros((X_test.shape[0],)), "classifier": y_test}, verbose=0)
    #print(f'Evaluación con test: Reconstruction Loss = {resultado[1]}, DKL Loss = {resultado[2]}, Classification Accuracy = {accuracy:.4f}')

    # Crear una figura con dos subplots para mostrar la pérdida y precisión
    plt.figure(figsize=(18, 5))

    # Subplot 1: Pérdida (Loss)
    plt.subplot(1, 2, 1)
    plt.plot(history.history['reconstruction_loss'], label='Reconstruction Loss')
    plt.plot(history.history['val_reconstruction_loss'], label='Val Reconstruction Loss')
    plt.plot(history.history['dkl_loss_loss'], label='DKL Loss')
    plt.plot(history.history['val_dkl_loss_loss'], label='Val DKL Loss')
    plt.title('Pérdida durante el entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('Error')
    plt.legend()

    # Subplot 2: Precisión (Accuracy)
    plt.subplot(1, 2, 2)
    plt.plot(history.history['classifier_accuracy'], label='Training Classification Accuracy')
    plt.plot(history.history['val_classifier_accuracy'], label='Validation Classification Accuracy')
    plt.title('Precisión durante el entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('Accuracy')
    plt.legend()

    # Mostrar las gráficas
    plt.show()

def evaluate_classifier(test_images, test_labels, model, num_classes=10):
    """
    Evalúa el rendimiento del clasificador, incluyendo la curva ROC y la matriz de confusión.

    Parámetros:
    test_images: Imágenes de prueba.
    test_labels: Etiquetas de prueba.
    model: El modelo clasificador.
    num_classes: Número de clases en la salida de clasificación.
    """
    # Obtener las predicciones del modelo
    y_pred_probs = model.predict(test_images)
    y_pred = np.argmax(y_pred_probs[-1], axis=1)

    # Calcular la curva ROC y el AUC para cada clase
    fpr = {}
    tpr = {}
    roc_auc = {}
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(np.argmax(test_labels,axis=1) == i, y_pred_probs[-1][:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Calcular la matriz de confusión
    conf_matrix = confusion_matrix(np.argmax(test_labels,axis=1), y_pred, normalize='true')

    # Configuración de la figura con dos gráficos (ROC y matriz de confusión)
    fig, (ax2, ax1) = plt.subplots(1, 2, figsize=(16, 8))

    # Graficar la curva ROC para cada clase
    for i in range(num_classes):
        ax1.plot(fpr[i], tpr[i], lw=2, label=f'{i}')
    ax1.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax1.set_xlim([0.0, 1.0])
    ax1.set_ylim([0.0, 1.05])
    ax1.set_xlabel('False Positive Rate')
    ax1.set_ylabel('True Positive Rate')
    ax1.set_title('Receiver Operating Characteristic')
    ax1.legend(loc="lower right")

    # Graficar la matriz de confusión normalizada
    disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=[f'{i}' for i in range(num_classes)])
    disp.plot(cmap=plt.cm.Blues, ax=ax2, colorbar=True)
    ax2.set_title('Normalized Confusion Matrix')

    plt.show()

    # Calcular las métricas y generar el reporte de clasificación
    precision = precision_score(np.argmax(test_labels,axis=1), y_pred, average='weighted')
    recall = recall_score(np.argmax(test_labels,axis=1), y_pred, average='weighted')
    f2 = fbeta_score(np.argmax(test_labels,axis=1), y_pred, beta=2, average='weighted')

    # Imprimir las métricas de precisión, recall y F2-score
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F2-score: {f2:.4f}")

    # Generar e imprimir el reporte de clasificación
    report = classification_report(np.argmax(test_labels,axis=1), y_pred, target_names=[f'{i}' for i in range(num_classes)])
    print(report)

import tensorflow as tf
import tensorflow as tf
from tensorflow import keras

import tensorflow as tf
from tensorflow import keras

class mmd_loss(keras.losses.Loss):
    def __init__(self,plot=False):
        super(mmd_loss, self).__init__()
        self.plot=plot

    def call(self, y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # Calcular la matriz de distancias entre y_true
        dist_matrix = self.cdist(y_true, y_true)

        # Calcular la parte triangular superior, excluyendo la diagonal
        upper_triangular = tf.linalg.band_part(dist_matrix, 0, -1)  # Parte triangular superior
        upper_triangular = tf.linalg.set_diag(upper_triangular, tf.zeros(tf.shape(dist_matrix)[0]))  # Excluir la diagonal

        # Extraer los valores no cero de la parte triangular superior
        non_zero_elements = tf.boolean_mask(upper_triangular, upper_triangular > 0)

        # Calcular sigma dinámicamente como la media de la triangular superior
        sigma = tf.reduce_mean(non_zero_elements)

        # Calcular las matrices de kernel usando el sigma dinámico
        K_yy = self.gaussian_kernel_matrix(y_true, y_true, sigma)
        K_ff = self.gaussian_kernel_matrix(y_pred, y_pred, sigma)
        K_yf = self.gaussian_kernel_matrix(y_true, y_pred, sigma)

        # Calcular la MMD: usar reduce_mean para obtener un escalar
        mmd = tf.reduce_mean(K_yy) + tf.reduce_mean(K_ff) - 2 * tf.reduce_mean(K_yf)
        if self.plot:
            plt.imshow(K_yf)
            plt.colorbar()
            plt.show()
        return 50*mmd

    def cdist(self, XA, XB):
        """
        Calcula la distancia euclidiana entre cada par de puntos de XA y XB.
        """
        # Expandir las dimensiones para hacer las diferencias entre todos los pares
        XA_exp = tf.expand_dims(XA, axis=1)  # (m, 1, d)
        XB_exp = tf.expand_dims(XB, axis=0)  # (1, n, d)
        # Calcular la distancia euclidiana
        dist_matrix = tf.reduce_sum(tf.square(XA_exp - XB_exp), axis=-1)
        return dist_matrix

    def gaussian_kernel_matrix(self, x, y, sigma):
        kernel = tf.exp(-self.cdist(x, y) / (2 * sigma ** 2))
        return kernel
# Out:
# Requirement already satisfied: tf-keras-vis in /usr/local/lib/python3.10/dist-packages (0.8.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tf-keras-vis) (1.13.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from tf-keras-vis) (10.4.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.10/dist-packages (from tf-keras-vis) (1.2.14)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from tf-keras-vis) (2.35.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tf-keras-vis) (24.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->tf-keras-vis) (1.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio->tf-keras-vis) (1.26.4)

# %% [markdown]
# # Custom loss COCO

# %%
class COCO_loss(tf.keras.losses.Loss):
    def __init__(self, lambda_init=1.0, gamma_init=1.0,plot=False):
        super(COCO_loss, self).__init__()
        self.lambda_value = tf.Variable(lambda_init, dtype=tf.float32, trainable=True)
        self.gamma_value = tf.Variable(gamma_init, dtype=tf.float32, trainable=True)
        self.plot=plot
    def call(self, y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # Calcular sigma dinámico como en el código original
        sigma1 = self.calculate_sigma(y_true)
        sigma2 = sigma1#self.calculate_sigma(y_pred)

        # Calcular las matrices de kernel usando el sigma dinámico
        K_y = self.gaussian_kernel_matrix(y_true, y_true, sigma1)
        K_x = self.gaussian_kernel_matrix(y_pred, y_pred, sigma2)

        # H es la matriz centralizadora
        n = tf.shape(K_x)[0]  # Usamos tf.shape para obtener el tamaño dinámico
        n_float = tf.cast(n, tf.float32)  # Asegurarse de que n sea float32 para las operaciones
        H = tf.eye(n, dtype=tf.float32) - (1/n_float) * tf.ones((n, n), dtype=tf.float32)
        K = tf.matmul(tf.matmul(H, K_x), H)
        L = tf.matmul(tf.matmul(H, K_y), H)

        # Como alpha y beta son vectores de unos, podemos simplificar usando reduce_mean
        alpha = tf.ones((n, 1), dtype=tf.float32)  # Vector de unos
        beta = tf.ones((n, 1), dtype=tf.float32)   # Vector de unos

        # Producto matricial entre K y L
        term1 = -1 / n_float * tf.matmul(tf.matmul(tf.transpose(alpha), K), tf.matmul(L, beta))
        term2 = (1/ 2) * (tf.matmul(tf.transpose(alpha), tf.matmul(K, alpha)) - 1)
        term3 = (1/ 2) * (tf.matmul(tf.transpose(beta), tf.matmul(L, beta)) - 1)
        cce = tf.keras.losses.CategoricalCrossentropy()
        cce(y_true, y_pred)
        # La pérdida final
        loss = cce(y_true, y_pred) +1e10*term1#+term1 + term2 + term3
        if self.plot:
            plt.imshow(K_y)
            plt.colorbar()
            plt.show()
        return loss

    def calculate_sigma(self, y):
        # Calcular la matriz de distancias entre y_true
        dist_matrix = self.cdist(y, y)

        # Calcular la parte triangular superior, excluyendo la diagonal
        upper_triangular = tf.linalg.band_part(dist_matrix, 0, -1)  # Parte triangular superior
        upper_triangular = tf.linalg.set_diag(upper_triangular, tf.zeros_like(tf.linalg.diag_part(dist_matrix)))  # Excluir la diagonal

        # Extraer los valores no cero de la parte triangular superior
        non_zero_elements = tf.boolean_mask(upper_triangular, upper_triangular > 0)

        # Calcular sigma dinámicamente como la media de la triangular superior
        sigma = tf.reduce_mean(non_zero_elements)
        return sigma

    def cdist(self, XA, XB):
        # Cálculo de la distancia euclidiana entre XA y XB
        XA_exp = tf.expand_dims(XA, axis=1)
        XB_exp = tf.expand_dims(XB, axis=0)
        dist_matrix = tf.reduce_sum(tf.square(XA_exp - XB_exp), axis=-1)
        return dist_matrix

    def gaussian_kernel_matrix(self, x, y, sigma):
        kernel = tf.exp(-self.cdist(x, y) / (2 * sigma ** 2))
        return kernel

# %% [markdown]
# ##Evaluación COCO

# %%
import tensorflow as tf
import numpy as np

# Generar datos sintéticos
num_samples = 500  # Número de muestras
num_classes = 10    # Número de clases

# Etiquetas sintéticas: enteros aleatorios entre 0 y num_classes - 1
y_true = np.random.randint(0, num_classes, size=num_samples)

# Predicciones sintéticas: probabilidades aleatorias (suma de probabilidades por fila = 1)
y_pred = np.random.rand(num_samples, num_classes)
y_pred = y_pred / np.sum(y_pred, axis=1, keepdims=True)  # Normalizar para que sean probabilidades
ind= np.argsort(y_true)
ind
# Convertir y_true a "one-hot" para que coincida con y_pred en dimensiones
y_true_one_hot = tf.keras.utils.to_categorical(y_true[ind], num_classes=num_classes)

# Convertir a tensores de TensorFlow
y_true_tensor = tf.convert_to_tensor(y_true, dtype=tf.int32)  # Etiquetas como enteros
y_true_one_hot_tensor = tf.convert_to_tensor(y_true_one_hot, dtype=tf.float32)  # Etiquetas "one-hot"
y_pred_tensor = tf.convert_to_tensor(y_pred, dtype=tf.float32)  # Predicciones como flotantes

# Aplicar la función de pérdida sparse_categorical_crossentropy
loss = tf.keras.losses.sparse_categorical_crossentropy(y_true_tensor, y_pred_tensor)

# Instanciar la pérdida personalizada con sigma=1.0
mmd_loss_fn = COCO_loss(plot=True)

# Calcular la pérdida MMD utilizando las etiquetas "one-hot"
mmd_value = mmd_loss_fn(y_true_one_hot_tensor, y_true_one_hot_tensor)

# %% [markdown]
# # Modelo

# %% [markdown]
# **Descripción del Código**
#
# 1. **Configuración Inicial**:
#    - Se configuran semillas para reproducibilidad en TensorFlow y NumPy.
#    - Se definen parámetros para la función de pérdida y el tamaño de los codificadores.
#    - `losses` define la función de pérdida escalada para el autoencoder variacional.
#
# 2. **Definición de la Arquitectura del Modelo**:
#    - **Encoder**:
#      - Se construye con capas convolucionales seguidas de `MaxPooling` para extraer características y reducir la dimensionalidad.
#      - Utiliza `LeakyReLU` como función de activación.
#      - Finalmente, las características extraídas se aplanan y se pasan a través de capas densas para obtener las medias (`codings_mean`) y logaritmos de varianzas (`codings_log_var`) de las codificaciones.
#      - La capa `Sampling` genera las codificaciones finales a partir de estas medias y varianzas.
#      - Se añade una capa densa para la salida de clasificación (`classifier_output`), con activación `softmax` para clasificación en múltiples clases.
#
#    - **Decoder**:
#      - Comienza con una capa densa que expande las codificaciones a una forma adecuada para la reconstrucción.
#      - Utiliza capas `Conv2DTranspose` para reconstruir la imagen original desde las codificaciones.
#      - Se aplican `BatchNormalization` y `LeakyReLU` después de cada capa convolucional transpuesta.
#
# 3. **Definición de Modelos**:
#    - `variational_encoder` es el modelo del encoder que toma las imágenes de entrada y produce las codificaciones y la salida de clasificación.
#    - `variational_decoder` es el modelo del decoder que toma las codificaciones y produce las imágenes reconstruidas.
#
# 4. **Pérdida DKL (Kullback-Leibler Divergence)**:
#    - Se calcula la pérdida DKL como una métrica adicional y se normaliza.
#    - `dkl_output` es la salida de la pérdida DKL que se usa en la compilación del modelo.
#
# 5. **Compilación del Modelo**:
#    - `variational_ae` combina el encoder y el decoder en un solo modelo con tres salidas: reconstrucción, pérdida DKL y salida de clasificación.
#    - Se compila el modelo con las pérdidas definidas para cada salida y se usa la métrica de precisión para la salida de clasificación.
#
# 6. **Entrenamiento del Modelo**:
#    - El modelo se entrena utilizando `X_train` y `y_train` para las imágenes y las etiquetas, respectivamente.
#    - Se realiza la validación utilizando `X_valid` y `y_valid` con las mismas pérdidas y métricas definidas para la validación.
#
# Este código define y entrena un autoencoder variacional con capacidades de clasificación, utilizando un encoder y un decoder para la reconstrucción de imágenes y la clasificación de etiquetas.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.losses import BinaryCrossentropy
# Definir Sampling layer
class Sampling(keras.layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# Definir el modelo basado en la estructura propuesta
def model_class(input_shape=(28, 28, 1), num_classes=10, latent_dim=128):
    # Encoder
    inputs = tf.keras.layers.Input(shape=input_shape)
    x = tf.keras.layers.Conv2D(64, kernel_size=2,activation='leaky_relu', padding='same', name='conv1')(inputs)
    x = tf.keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
    x = tf.keras.layers.Conv2D(128, kernel_size=2, activation='leaky_relu', padding='same', name='conv2')(x)
    x = tf.keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
    x = tf.keras.layers.Conv2D(256, kernel_size=2, activation='leaky_relu', padding='same', name='conv3')(x)
    x = tf.keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
    x = tf.keras.layers.Flatten()(x)
    #x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dense(128, activation='leaky_relu', name='Capa_h')(x)
    #x = tf.keras.layers.BatchNormalization()(x)
    z_mean = tf.keras.layers.Dense(latent_dim, name='z_mean')(x)
    z_log_var = tf.keras.layers.Dense(latent_dim, name='z_log_var')(x)
    z = Sampling(name='sampling')([z_mean, z_log_var])
    latent_loss = -5 * 0.5 * K.sum(1 +z_log_var - K.exp(z_log_var) - K.square(z_mean), axis=-1)
    dkl_output = K.mean(latent_loss) / 784.0
    dkl_output = keras.layers.Lambda(lambda x: x, name="dkl_loss")(dkl_output)
        # Softmax output (classification)
    softmax_output = tf.keras.layers.Dense(num_classes, activation='softmax', name='classifier')(z)

    # Decoder
    x = tf.keras.layers.Dense(7 * 7 * 64, activation='leaky_relu')(z)
    x = tf.keras.layers.Reshape((7, 7, 64))(x)
    x = tf.keras.layers.Conv2DTranspose(64,activation='leaky_relu', kernel_size=3, strides=2, padding="same", name='ConvT1')(x)
    #x = tf.keras.layers.LeakyReLU()(x)
    x = tf.keras.layers.Conv2DTranspose(32, activation='leaky_relu',kernel_size=3, strides=2, padding="same", name='ConvT2')(x)
    #x = tf.keras.layers.LeakyReLU()(x)
    x = tf.keras.layers.Conv2DTranspose(16,activation='leaky_relu', kernel_size=3, strides=1, padding="same", name='ConvT3')(x)
    #x = tf.keras.layers.LeakyReLU()(x)
    reconstruction = tf.keras.layers.Conv2DTranspose(input_shape[2], kernel_size=3, padding="same", activation="sigmoid", name='reconstruction')(x)

    # VAE Model
    vae = tf.keras.models.Model(inputs, [reconstruction,dkl_output , softmax_output], name='vae')
    return vae

# Definir la pérdida de reconstrucción
def reconstruction_loss(y_true, y_pred):
    binary_crossentropy = tf.keras.losses.BinaryCrossentropy()
    return binary_crossentropy(y_true, y_pred)

# Definir la pérdida DKL
def dkl_loss(y_true, y_pred):
    return y_pred  # El valor ya está calculado como la salida

# Definir la pérdida MMD (ya asumimos que la has definido como mmd_loss en otro lugar)
# Aquí utilizamos la versión anterior o una versión adaptada de mmd_loss

# Configurar el modelo
input_shape = (28, 28, 1)
num_classes = 10
latent_dim = 256
learning_rate = 1e-3
model = model_class(input_shape, num_classes, latent_dim)
# Compilación del modelo con pérdidas múltiples
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss={'reconstruction': reconstruction_loss,
                    'dkl_loss': dkl_loss,
                    'classifier': COCO_loss()},
              loss_weights={'reconstruction': 0.4,
                            'dkl_loss': 0.2,
                            'classifier': 0.4},
              metrics={'classifier': ['accuracy']}
             )

# Datos de entrenamiento (X_train, y_train) y validación (X_valid, y_valid)
# Por simplicidad, aquí asumimos que ya están definidos como variables
# Entrenamiento del modelo
history = model.fit(X_train, {"reconstruction": X_train, "dkl_loss": np.zeros((X_train.shape[0], latent_dim)), "classifier": tf.keras.utils.to_categorical(y_train)},
                    epochs=150, batch_size=64,
                    validation_data=(X_valid, {"reconstruction": X_valid, "dkl_loss": np.zeros((X_valid.shape[0], latent_dim)), "classifier": tf.keras.utils.to_categorical(y_valid)}))
# Out:
# Epoch 1/150
# 860/860 [==============================] - 34s 23ms/step - loss: 0.4639 - reconstruction_loss: 0.3561 - dkl_loss_loss: 0.2290 - classifier_loss: 0.6891 - classifier_accuracy: 0.7474 - val_loss: 0.3588 - val_reconstruction_loss: 0.3417 - val_dkl_loss_loss: 0.1764 - val_classifier_loss: 0.4671 - val_classifier_accuracy: 0.8202
# Epoch 2/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.3420 - reconstruction_loss: 0.3370 - dkl_loss_loss: 0.1918 - classifier_loss: 0.4221 - classifier_accuracy: 0.8488 - val_loss: 0.3308 - val_reconstruction_loss: 0.3362 - val_dkl_loss_loss: 0.1977 - val_classifier_loss: 0.3921 - val_classifier_accuracy: 0.8542
# Epoch 3/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.3150 - reconstruction_loss: 0.3331 - dkl_loss_loss: 0.1866 - classifier_loss: 0.3612 - classifier_accuracy: 0.8691 - val_loss: 0.3053 - val_reconstruction_loss: 0.3338 - val_dkl_loss_loss: 0.1747 - val_classifier_loss: 0.3420 - val_classifier_accuracy: 0.8754
# Epoch 4/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.3023 - reconstruction_loss: 0.3304 - dkl_loss_loss: 0.1849 - classifier_loss: 0.3329 - classifier_accuracy: 0.8810 - val_loss: 0.3020 - val_reconstruction_loss: 0.3299 - val_dkl_loss_loss: 0.1896 - val_classifier_loss: 0.3303 - val_classifier_accuracy: 0.8800
# Epoch 5/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.2910 - reconstruction_loss: 0.3282 - dkl_loss_loss: 0.1852 - classifier_loss: 0.3066 - classifier_accuracy: 0.8901 - val_loss: 0.2934 - val_reconstruction_loss: 0.3298 - val_dkl_loss_loss: 0.1821 - val_classifier_loss: 0.3128 - val_classifier_accuracy: 0.8874
# Epoch 6/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.2830 - reconstruction_loss: 0.3263 - dkl_loss_loss: 0.1814 - classifier_loss: 0.2905 - classifier_accuracy: 0.8969 - val_loss: 0.2884 - val_reconstruction_loss: 0.3248 - val_dkl_loss_loss: 0.1942 - val_classifier_loss: 0.2990 - val_classifier_accuracy: 0.8978
# Epoch 7/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.2736 - reconstruction_loss: 0.3238 - dkl_loss_loss: 0.1785 - classifier_loss: 0.2709 - classifier_accuracy: 0.9028 - val_loss: 0.2863 - val_reconstruction_loss: 0.3252 - val_dkl_loss_loss: 0.1667 - val_classifier_loss: 0.3073 - val_classifier_accuracy: 0.8958
# Epoch 8/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.2677 - reconstruction_loss: 0.3215 - dkl_loss_loss: 0.1764 - classifier_loss: 0.2596 - classifier_accuracy: 0.9064 - val_loss: 0.2770 - val_reconstruction_loss: 0.3224 - val_dkl_loss_loss: 0.1652 - val_classifier_loss: 0.2875 - val_classifier_accuracy: 0.8954
# Epoch 9/150
# 860/860 [==============================] - 12s 14ms/step - loss: 0.2591 - reconstruction_loss: 0.3194 - dkl_loss_loss: 0.1725 - classifier_loss: 0.2421 - classifier_accuracy: 0.9137 - val_loss: 0.2804 - val_reconstruction_loss: 0.3213 - val_dkl_loss_loss: 0.1678 - val_classifier_loss: 0.2959 - val_classifier_accuracy: 0.8994
# Epoch 10/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.2522 - reconstruction_loss: 0.3178 - dkl_loss_loss: 0.1683 - classifier_loss: 0.2285 - classifier_accuracy: 0.9180 - val_loss: 0.2649 - val_reconstruction_loss: 0.3212 - val_dkl_loss_loss: 0.1541 - val_classifier_loss: 0.2639 - val_classifier_accuracy: 0.9080
# Epoch 11/150
# 860/860 [==============================] - 17s 19ms/step - loss: 0.2451 - reconstruction_loss: 0.3165 - dkl_loss_loss: 0.1640 - classifier_loss: 0.2142 - classifier_accuracy: 0.9233 - val_loss: 0.2613 - val_reconstruction_loss: 0.3200 - val_dkl_loss_loss: 0.1462 - val_classifier_loss: 0.2602 - val_classifier_accuracy: 0.9066
# Epoch 12/150
# 860/860 [==============================] - 12s 14ms/step - loss: 0.2394 - reconstruction_loss: 0.3155 - dkl_loss_loss: 0.1600 - classifier_loss: 0.2029 - classifier_accuracy: 0.9265 - val_loss: 0.2591 - val_reconstruction_loss: 0.3175 - val_dkl_loss_loss: 0.1534 - val_classifier_loss: 0.2535 - val_classifier_accuracy: 0.9086
# Epoch 13/150
# 860/860 [==============================] - 18s 21ms/step - loss: 0.2350 - reconstruction_loss: 0.3143 - dkl_loss_loss: 0.1568 - classifier_loss: 0.1947 - classifier_accuracy: 0.9295 - val_loss: 0.2553 - val_reconstruction_loss: 0.3147 - val_dkl_loss_loss: 0.1553 - val_classifier_loss: 0.2459 - val_classifier_accuracy: 0.9116
# Epoch 14/150
# 860/860 [==============================] - 16s 18ms/step - loss: 0.2293 - reconstruction_loss: 0.3133 - dkl_loss_loss: 0.1542 - classifier_loss: 0.1829 - classifier_accuracy: 0.9341 - val_loss: 0.2657 - val_reconstruction_loss: 0.3153 - val_dkl_loss_loss: 0.1453 - val_classifier_loss: 0.2762 - val_classifier_accuracy: 0.9102
# Epoch 15/150
# 860/860 [==============================] - 14s 16ms/step - loss: 0.2251 - reconstruction_loss: 0.3125 - dkl_loss_loss: 0.1511 - classifier_loss: 0.1748 - classifier_accuracy: 0.9365 - val_loss: 0.2532 - val_reconstruction_loss: 0.3147 - val_dkl_loss_loss: 0.1471 - val_classifier_loss: 0.2448 - val_classifier_accuracy: 0.9140
# Epoch 16/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.2198 - reconstruction_loss: 0.3117 - dkl_loss_loss: 0.1484 - classifier_loss: 0.1637 - classifier_accuracy: 0.9411 - val_loss: 0.2515 - val_reconstruction_loss: 0.3145 - val_dkl_loss_loss: 0.1379 - val_classifier_loss: 0.2453 - val_classifier_accuracy: 0.9138
# Epoch 17/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.2160 - reconstruction_loss: 0.3113 - dkl_loss_loss: 0.1450 - classifier_loss: 0.1562 - classifier_accuracy: 0.9429 - val_loss: 0.2568 - val_reconstruction_loss: 0.3124 - val_dkl_loss_loss: 0.1397 - val_classifier_loss: 0.2598 - val_classifier_accuracy: 0.9120
# Epoch 18/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.2115 - reconstruction_loss: 0.3103 - dkl_loss_loss: 0.1433 - classifier_loss: 0.1467 - classifier_accuracy: 0.9463 - val_loss: 0.2521 - val_reconstruction_loss: 0.3140 - val_dkl_loss_loss: 0.1343 - val_classifier_loss: 0.2491 - val_classifier_accuracy: 0.9156
# Epoch 19/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.2085 - reconstruction_loss: 0.3103 - dkl_loss_loss: 0.1408 - classifier_loss: 0.1406 - classifier_accuracy: 0.9482 - val_loss: 0.2538 - val_reconstruction_loss: 0.3114 - val_dkl_loss_loss: 0.1398 - val_classifier_loss: 0.2532 - val_classifier_accuracy: 0.9122
# Epoch 20/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.2040 - reconstruction_loss: 0.3096 - dkl_loss_loss: 0.1389 - classifier_loss: 0.1308 - classifier_accuracy: 0.9523 - val_loss: 0.2589 - val_reconstruction_loss: 0.3119 - val_dkl_loss_loss: 0.1459 - val_classifier_loss: 0.2624 - val_classifier_accuracy: 0.9132
# Epoch 21/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.2011 - reconstruction_loss: 0.3092 - dkl_loss_loss: 0.1377 - classifier_loss: 0.1246 - classifier_accuracy: 0.9547 - val_loss: 0.2515 - val_reconstruction_loss: 0.3111 - val_dkl_loss_loss: 0.1310 - val_classifier_loss: 0.2522 - val_classifier_accuracy: 0.9142
# Epoch 22/150
# 860/860 [==============================] - 12s 14ms/step - loss: 0.1973 - reconstruction_loss: 0.3089 - dkl_loss_loss: 0.1350 - classifier_loss: 0.1169 - classifier_accuracy: 0.9566 - val_loss: 0.2489 - val_reconstruction_loss: 0.3120 - val_dkl_loss_loss: 0.1259 - val_classifier_loss: 0.2472 - val_classifier_accuracy: 0.9156
# Epoch 23/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1960 - reconstruction_loss: 0.3088 - dkl_loss_loss: 0.1345 - classifier_loss: 0.1140 - classifier_accuracy: 0.9587 - val_loss: 0.2506 - val_reconstruction_loss: 0.3105 - val_dkl_loss_loss: 0.1310 - val_classifier_loss: 0.2506 - val_classifier_accuracy: 0.9154
# Epoch 24/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1918 - reconstruction_loss: 0.3083 - dkl_loss_loss: 0.1328 - classifier_loss: 0.1048 - classifier_accuracy: 0.9618 - val_loss: 0.2575 - val_reconstruction_loss: 0.3102 - val_dkl_loss_loss: 0.1324 - val_classifier_loss: 0.2673 - val_classifier_accuracy: 0.9126
# Epoch 25/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1903 - reconstruction_loss: 0.3082 - dkl_loss_loss: 0.1325 - classifier_loss: 0.1014 - classifier_accuracy: 0.9632 - val_loss: 0.2576 - val_reconstruction_loss: 0.3101 - val_dkl_loss_loss: 0.1339 - val_classifier_loss: 0.2671 - val_classifier_accuracy: 0.9174
# Epoch 26/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1869 - reconstruction_loss: 0.3077 - dkl_loss_loss: 0.1306 - classifier_loss: 0.0942 - classifier_accuracy: 0.9661 - val_loss: 0.2632 - val_reconstruction_loss: 0.3113 - val_dkl_loss_loss: 0.1250 - val_classifier_loss: 0.2843 - val_classifier_accuracy: 0.9110
# Epoch 27/150
# 860/860 [==============================] - 10s 11ms/step - loss: 0.1852 - reconstruction_loss: 0.3074 - dkl_loss_loss: 0.1306 - classifier_loss: 0.0902 - classifier_accuracy: 0.9676 - val_loss: 0.2594 - val_reconstruction_loss: 0.3098 - val_dkl_loss_loss: 0.1234 - val_classifier_loss: 0.2770 - val_classifier_accuracy: 0.9158
# Epoch 28/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1825 - reconstruction_loss: 0.3075 - dkl_loss_loss: 0.1291 - classifier_loss: 0.0842 - classifier_accuracy: 0.9698 - val_loss: 0.2538 - val_reconstruction_loss: 0.3105 - val_dkl_loss_loss: 0.1263 - val_classifier_loss: 0.2608 - val_classifier_accuracy: 0.9210
# Epoch 29/150
# 860/860 [==============================] - 12s 14ms/step - loss: 0.1822 - reconstruction_loss: 0.3070 - dkl_loss_loss: 0.1293 - classifier_loss: 0.0838 - classifier_accuracy: 0.9703 - val_loss: 0.2583 - val_reconstruction_loss: 0.3103 - val_dkl_loss_loss: 0.1174 - val_classifier_loss: 0.2768 - val_classifier_accuracy: 0.9168
# Epoch 30/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1792 - reconstruction_loss: 0.3067 - dkl_loss_loss: 0.1283 - classifier_loss: 0.0771 - classifier_accuracy: 0.9727 - val_loss: 0.2680 - val_reconstruction_loss: 0.3088 - val_dkl_loss_loss: 0.1316 - val_classifier_loss: 0.2955 - val_classifier_accuracy: 0.9160
# Epoch 31/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1779 - reconstruction_loss: 0.3067 - dkl_loss_loss: 0.1259 - classifier_loss: 0.0751 - classifier_accuracy: 0.9728 - val_loss: 0.2654 - val_reconstruction_loss: 0.3081 - val_dkl_loss_loss: 0.1262 - val_classifier_loss: 0.2923 - val_classifier_accuracy: 0.9178
# Epoch 32/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1757 - reconstruction_loss: 0.3064 - dkl_loss_loss: 0.1253 - classifier_loss: 0.0701 - classifier_accuracy: 0.9753 - val_loss: 0.2690 - val_reconstruction_loss: 0.3066 - val_dkl_loss_loss: 0.1365 - val_classifier_loss: 0.2976 - val_classifier_accuracy: 0.9194
# Epoch 33/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1759 - reconstruction_loss: 0.3062 - dkl_loss_loss: 0.1270 - classifier_loss: 0.0700 - classifier_accuracy: 0.9744 - val_loss: 0.2739 - val_reconstruction_loss: 0.3078 - val_dkl_loss_loss: 0.1268 - val_classifier_loss: 0.3136 - val_classifier_accuracy: 0.9158
# Epoch 34/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1722 - reconstruction_loss: 0.3061 - dkl_loss_loss: 0.1237 - classifier_loss: 0.0627 - classifier_accuracy: 0.9777 - val_loss: 0.2724 - val_reconstruction_loss: 0.3083 - val_dkl_loss_loss: 0.1208 - val_classifier_loss: 0.3123 - val_classifier_accuracy: 0.9200
# Epoch 35/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1716 - reconstruction_loss: 0.3059 - dkl_loss_loss: 0.1229 - classifier_loss: 0.0617 - classifier_accuracy: 0.9781 - val_loss: 0.2802 - val_reconstruction_loss: 0.3073 - val_dkl_loss_loss: 0.1280 - val_classifier_loss: 0.3293 - val_classifier_accuracy: 0.9168
# Epoch 36/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1715 - reconstruction_loss: 0.3056 - dkl_loss_loss: 0.1235 - classifier_loss: 0.0614 - classifier_accuracy: 0.9780 - val_loss: 0.2806 - val_reconstruction_loss: 0.3098 - val_dkl_loss_loss: 0.1196 - val_classifier_loss: 0.3320 - val_classifier_accuracy: 0.9108
# Epoch 37/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1695 - reconstruction_loss: 0.3055 - dkl_loss_loss: 0.1219 - classifier_loss: 0.0574 - classifier_accuracy: 0.9796 - val_loss: 0.2781 - val_reconstruction_loss: 0.3076 - val_dkl_loss_loss: 0.1240 - val_classifier_loss: 0.3258 - val_classifier_accuracy: 0.9132
# Epoch 38/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1677 - reconstruction_loss: 0.3054 - dkl_loss_loss: 0.1221 - classifier_loss: 0.0528 - classifier_accuracy: 0.9812 - val_loss: 0.2846 - val_reconstruction_loss: 0.3077 - val_dkl_loss_loss: 0.1222 - val_classifier_loss: 0.3428 - val_classifier_accuracy: 0.9116
# Epoch 39/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1682 - reconstruction_loss: 0.3050 - dkl_loss_loss: 0.1215 - classifier_loss: 0.0548 - classifier_accuracy: 0.9802 - val_loss: 0.2725 - val_reconstruction_loss: 0.3066 - val_dkl_loss_loss: 0.1260 - val_classifier_loss: 0.3117 - val_classifier_accuracy: 0.9164
# Epoch 40/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1675 - reconstruction_loss: 0.3050 - dkl_loss_loss: 0.1221 - classifier_loss: 0.0527 - classifier_accuracy: 0.9809 - val_loss: 0.3019 - val_reconstruction_loss: 0.3069 - val_dkl_loss_loss: 0.1232 - val_classifier_loss: 0.3862 - val_classifier_accuracy: 0.9058
# Epoch 41/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1653 - reconstruction_loss: 0.3048 - dkl_loss_loss: 0.1211 - classifier_loss: 0.0478 - classifier_accuracy: 0.9831 - val_loss: 0.2841 - val_reconstruction_loss: 0.3067 - val_dkl_loss_loss: 0.1216 - val_classifier_loss: 0.3426 - val_classifier_accuracy: 0.9200
# Epoch 42/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1646 - reconstruction_loss: 0.3046 - dkl_loss_loss: 0.1200 - classifier_loss: 0.0468 - classifier_accuracy: 0.9837 - val_loss: 0.2850 - val_reconstruction_loss: 0.3082 - val_dkl_loss_loss: 0.1165 - val_classifier_loss: 0.3460 - val_classifier_accuracy: 0.9174
# Epoch 43/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1655 - reconstruction_loss: 0.3044 - dkl_loss_loss: 0.1214 - classifier_loss: 0.0486 - classifier_accuracy: 0.9828 - val_loss: 0.2899 - val_reconstruction_loss: 0.3059 - val_dkl_loss_loss: 0.1219 - val_classifier_loss: 0.3578 - val_classifier_accuracy: 0.9212
# Epoch 44/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1622 - reconstruction_loss: 0.3044 - dkl_loss_loss: 0.1193 - classifier_loss: 0.0415 - classifier_accuracy: 0.9849 - val_loss: 0.2894 - val_reconstruction_loss: 0.3067 - val_dkl_loss_loss: 0.1179 - val_classifier_loss: 0.3578 - val_classifier_accuracy: 0.9190
# Epoch 45/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1630 - reconstruction_loss: 0.3043 - dkl_loss_loss: 0.1192 - classifier_loss: 0.0436 - classifier_accuracy: 0.9845 - val_loss: 0.2856 - val_reconstruction_loss: 0.3065 - val_dkl_loss_loss: 0.1182 - val_classifier_loss: 0.3483 - val_classifier_accuracy: 0.9168
# Epoch 46/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1631 - reconstruction_loss: 0.3040 - dkl_loss_loss: 0.1199 - classifier_loss: 0.0439 - classifier_accuracy: 0.9842 - val_loss: 0.2938 - val_reconstruction_loss: 0.3061 - val_dkl_loss_loss: 0.1203 - val_classifier_loss: 0.3684 - val_classifier_accuracy: 0.9164
# Epoch 47/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1620 - reconstruction_loss: 0.3041 - dkl_loss_loss: 0.1180 - classifier_loss: 0.0419 - classifier_accuracy: 0.9852 - val_loss: 0.2918 - val_reconstruction_loss: 0.3059 - val_dkl_loss_loss: 0.1138 - val_classifier_loss: 0.3666 - val_classifier_accuracy: 0.9178
# Epoch 48/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1593 - reconstruction_loss: 0.3037 - dkl_loss_loss: 0.1171 - classifier_loss: 0.0358 - classifier_accuracy: 0.9878 - val_loss: 0.2839 - val_reconstruction_loss: 0.3067 - val_dkl_loss_loss: 0.1107 - val_classifier_loss: 0.3476 - val_classifier_accuracy: 0.9160
# Epoch 49/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1617 - reconstruction_loss: 0.3038 - dkl_loss_loss: 0.1182 - classifier_loss: 0.0414 - classifier_accuracy: 0.9855 - val_loss: 0.3000 - val_reconstruction_loss: 0.3043 - val_dkl_loss_loss: 0.1261 - val_classifier_loss: 0.3827 - val_classifier_accuracy: 0.9166
# Epoch 50/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1607 - reconstruction_loss: 0.3037 - dkl_loss_loss: 0.1182 - classifier_loss: 0.0390 - classifier_accuracy: 0.9866 - val_loss: 0.2873 - val_reconstruction_loss: 0.3051 - val_dkl_loss_loss: 0.1204 - val_classifier_loss: 0.3529 - val_classifier_accuracy: 0.9172
# Epoch 51/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1586 - reconstruction_loss: 0.3036 - dkl_loss_loss: 0.1168 - classifier_loss: 0.0344 - classifier_accuracy: 0.9878 - val_loss: 0.3260 - val_reconstruction_loss: 0.3079 - val_dkl_loss_loss: 0.1141 - val_classifier_loss: 0.4502 - val_classifier_accuracy: 0.9008
# Epoch 52/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1587 - reconstruction_loss: 0.3033 - dkl_loss_loss: 0.1166 - classifier_loss: 0.0352 - classifier_accuracy: 0.9873 - val_loss: 0.2852 - val_reconstruction_loss: 0.3053 - val_dkl_loss_loss: 0.1147 - val_classifier_loss: 0.3502 - val_classifier_accuracy: 0.9230
# Epoch 53/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1582 - reconstruction_loss: 0.3033 - dkl_loss_loss: 0.1163 - classifier_loss: 0.0341 - classifier_accuracy: 0.9883 - val_loss: 0.2939 - val_reconstruction_loss: 0.3053 - val_dkl_loss_loss: 0.1155 - val_classifier_loss: 0.3717 - val_classifier_accuracy: 0.9198
# Epoch 54/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1598 - reconstruction_loss: 0.3031 - dkl_loss_loss: 0.1188 - classifier_loss: 0.0370 - classifier_accuracy: 0.9865 - val_loss: 0.3020 - val_reconstruction_loss: 0.3057 - val_dkl_loss_loss: 0.1134 - val_classifier_loss: 0.3927 - val_classifier_accuracy: 0.9166
# Epoch 55/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1597 - reconstruction_loss: 0.3031 - dkl_loss_loss: 0.1161 - classifier_loss: 0.0380 - classifier_accuracy: 0.9863 - val_loss: 0.3133 - val_reconstruction_loss: 0.3067 - val_dkl_loss_loss: 0.1107 - val_classifier_loss: 0.4212 - val_classifier_accuracy: 0.9070
# Epoch 56/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1539 - reconstruction_loss: 0.3029 - dkl_loss_loss: 0.1127 - classifier_loss: 0.0255 - classifier_accuracy: 0.9915 - val_loss: 0.2991 - val_reconstruction_loss: 0.3048 - val_dkl_loss_loss: 0.1137 - val_classifier_loss: 0.3860 - val_classifier_accuracy: 0.9164
# Epoch 57/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1592 - reconstruction_loss: 0.3028 - dkl_loss_loss: 0.1174 - classifier_loss: 0.0364 - classifier_accuracy: 0.9868 - val_loss: 0.3071 - val_reconstruction_loss: 0.3051 - val_dkl_loss_loss: 0.1168 - val_classifier_loss: 0.4043 - val_classifier_accuracy: 0.9194
# Epoch 58/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1572 - reconstruction_loss: 0.3028 - dkl_loss_loss: 0.1163 - classifier_loss: 0.0319 - classifier_accuracy: 0.9888 - val_loss: 0.2933 - val_reconstruction_loss: 0.3050 - val_dkl_loss_loss: 0.1150 - val_classifier_loss: 0.3708 - val_classifier_accuracy: 0.9216
# Epoch 59/150
# 860/860 [==============================] - 16s 19ms/step - loss: 0.1568 - reconstruction_loss: 0.3028 - dkl_loss_loss: 0.1149 - classifier_loss: 0.0317 - classifier_accuracy: 0.9893 - val_loss: 0.3168 - val_reconstruction_loss: 0.3050 - val_dkl_loss_loss: 0.1249 - val_classifier_loss: 0.4246 - val_classifier_accuracy: 0.9144
# Epoch 60/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1566 - reconstruction_loss: 0.3027 - dkl_loss_loss: 0.1147 - classifier_loss: 0.0315 - classifier_accuracy: 0.9891 - val_loss: 0.2991 - val_reconstruction_loss: 0.3054 - val_dkl_loss_loss: 0.1093 - val_classifier_loss: 0.3877 - val_classifier_accuracy: 0.9194
# Epoch 61/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1561 - reconstruction_loss: 0.3026 - dkl_loss_loss: 0.1137 - classifier_loss: 0.0309 - classifier_accuracy: 0.9896 - val_loss: 0.3202 - val_reconstruction_loss: 0.3063 - val_dkl_loss_loss: 0.1167 - val_classifier_loss: 0.4357 - val_classifier_accuracy: 0.9134
# Epoch 62/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1549 - reconstruction_loss: 0.3025 - dkl_loss_loss: 0.1141 - classifier_loss: 0.0278 - classifier_accuracy: 0.9903 - val_loss: 0.3243 - val_reconstruction_loss: 0.3062 - val_dkl_loss_loss: 0.1128 - val_classifier_loss: 0.4483 - val_classifier_accuracy: 0.9108
# Epoch 63/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1554 - reconstruction_loss: 0.3025 - dkl_loss_loss: 0.1134 - classifier_loss: 0.0294 - classifier_accuracy: 0.9893 - val_loss: 0.3029 - val_reconstruction_loss: 0.3050 - val_dkl_loss_loss: 0.1110 - val_classifier_loss: 0.3967 - val_classifier_accuracy: 0.9186
# Epoch 64/150
# 860/860 [==============================] - 12s 13ms/step - loss: 0.1549 - reconstruction_loss: 0.3024 - dkl_loss_loss: 0.1146 - classifier_loss: 0.0276 - classifier_accuracy: 0.9903 - val_loss: 0.3066 - val_reconstruction_loss: 0.3040 - val_dkl_loss_loss: 0.1165 - val_classifier_loss: 0.4042 - val_classifier_accuracy: 0.9146
# Epoch 65/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1558 - reconstruction_loss: 0.3025 - dkl_loss_loss: 0.1132 - classifier_loss: 0.0303 - classifier_accuracy: 0.9895 - val_loss: 0.2960 - val_reconstruction_loss: 0.3040 - val_dkl_loss_loss: 0.1138 - val_classifier_loss: 0.3791 - val_classifier_accuracy: 0.9178
# Epoch 66/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1544 - reconstruction_loss: 0.3022 - dkl_loss_loss: 0.1130 - classifier_loss: 0.0274 - classifier_accuracy: 0.9903 - val_loss: 0.3247 - val_reconstruction_loss: 0.3037 - val_dkl_loss_loss: 0.1178 - val_classifier_loss: 0.4491 - val_classifier_accuracy: 0.9158
# Epoch 67/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1540 - reconstruction_loss: 0.3022 - dkl_loss_loss: 0.1133 - classifier_loss: 0.0262 - classifier_accuracy: 0.9905 - val_loss: 0.3380 - val_reconstruction_loss: 0.3055 - val_dkl_loss_loss: 0.1165 - val_classifier_loss: 0.4812 - val_classifier_accuracy: 0.9060
# Epoch 68/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1551 - reconstruction_loss: 0.3022 - dkl_loss_loss: 0.1131 - classifier_loss: 0.0289 - classifier_accuracy: 0.9897 - val_loss: 0.2965 - val_reconstruction_loss: 0.3037 - val_dkl_loss_loss: 0.1150 - val_classifier_loss: 0.3801 - val_classifier_accuracy: 0.9174
# Epoch 69/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1518 - reconstruction_loss: 0.3021 - dkl_loss_loss: 0.1110 - classifier_loss: 0.0220 - classifier_accuracy: 0.9927 - val_loss: 0.3166 - val_reconstruction_loss: 0.3048 - val_dkl_loss_loss: 0.1129 - val_classifier_loss: 0.4302 - val_classifier_accuracy: 0.9100
# Epoch 70/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1563 - reconstruction_loss: 0.3024 - dkl_loss_loss: 0.1141 - classifier_loss: 0.0313 - classifier_accuracy: 0.9888 - val_loss: 0.3090 - val_reconstruction_loss: 0.3041 - val_dkl_loss_loss: 0.1150 - val_classifier_loss: 0.4108 - val_classifier_accuracy: 0.9210
# Epoch 71/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1521 - reconstruction_loss: 0.3019 - dkl_loss_loss: 0.1113 - classifier_loss: 0.0226 - classifier_accuracy: 0.9925 - val_loss: 0.3366 - val_reconstruction_loss: 0.3056 - val_dkl_loss_loss: 0.1114 - val_classifier_loss: 0.4802 - val_classifier_accuracy: 0.9086
# Epoch 72/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1546 - reconstruction_loss: 0.3020 - dkl_loss_loss: 0.1130 - classifier_loss: 0.0280 - classifier_accuracy: 0.9906 - val_loss: 0.3107 - val_reconstruction_loss: 0.3051 - val_dkl_loss_loss: 0.1081 - val_classifier_loss: 0.4175 - val_classifier_accuracy: 0.9192
# Epoch 73/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1512 - reconstruction_loss: 0.3020 - dkl_loss_loss: 0.1090 - classifier_loss: 0.0216 - classifier_accuracy: 0.9924 - val_loss: 0.3184 - val_reconstruction_loss: 0.3047 - val_dkl_loss_loss: 0.1080 - val_classifier_loss: 0.4373 - val_classifier_accuracy: 0.9186
# Epoch 74/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1508 - reconstruction_loss: 0.3018 - dkl_loss_loss: 0.1098 - classifier_loss: 0.0204 - classifier_accuracy: 0.9932 - val_loss: 0.3200 - val_reconstruction_loss: 0.3038 - val_dkl_loss_loss: 0.1113 - val_classifier_loss: 0.4405 - val_classifier_accuracy: 0.9188
# Epoch 75/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1569 - reconstruction_loss: 0.3020 - dkl_loss_loss: 0.1133 - classifier_loss: 0.0335 - classifier_accuracy: 0.9883 - val_loss: 0.3346 - val_reconstruction_loss: 0.3036 - val_dkl_loss_loss: 0.1221 - val_classifier_loss: 0.4719 - val_classifier_accuracy: 0.9140
# Epoch 76/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1503 - reconstruction_loss: 0.3017 - dkl_loss_loss: 0.1096 - classifier_loss: 0.0193 - classifier_accuracy: 0.9931 - val_loss: 0.3243 - val_reconstruction_loss: 0.3054 - val_dkl_loss_loss: 0.1041 - val_classifier_loss: 0.4532 - val_classifier_accuracy: 0.9114
# Epoch 77/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1526 - reconstruction_loss: 0.3018 - dkl_loss_loss: 0.1102 - classifier_loss: 0.0247 - classifier_accuracy: 0.9918 - val_loss: 0.3406 - val_reconstruction_loss: 0.3041 - val_dkl_loss_loss: 0.1100 - val_classifier_loss: 0.4925 - val_classifier_accuracy: 0.9104
# Epoch 78/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1512 - reconstruction_loss: 0.3018 - dkl_loss_loss: 0.1093 - classifier_loss: 0.0215 - classifier_accuracy: 0.9929 - val_loss: 0.3450 - val_reconstruction_loss: 0.3042 - val_dkl_loss_loss: 0.1176 - val_classifier_loss: 0.4996 - val_classifier_accuracy: 0.9150
# Epoch 79/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1553 - reconstruction_loss: 0.3018 - dkl_loss_loss: 0.1127 - classifier_loss: 0.0301 - classifier_accuracy: 0.9895 - val_loss: 0.3145 - val_reconstruction_loss: 0.3027 - val_dkl_loss_loss: 0.1186 - val_classifier_loss: 0.4243 - val_classifier_accuracy: 0.9194
# Epoch 80/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1511 - reconstruction_loss: 0.3016 - dkl_loss_loss: 0.1109 - classifier_loss: 0.0207 - classifier_accuracy: 0.9934 - val_loss: 0.3103 - val_reconstruction_loss: 0.3027 - val_dkl_loss_loss: 0.1146 - val_classifier_loss: 0.4159 - val_classifier_accuracy: 0.9146
# Epoch 81/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1514 - reconstruction_loss: 0.3015 - dkl_loss_loss: 0.1108 - classifier_loss: 0.0215 - classifier_accuracy: 0.9924 - val_loss: 0.3086 - val_reconstruction_loss: 0.3048 - val_dkl_loss_loss: 0.1080 - val_classifier_loss: 0.4128 - val_classifier_accuracy: 0.9210
# Epoch 82/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1528 - reconstruction_loss: 0.3017 - dkl_loss_loss: 0.1114 - classifier_loss: 0.0247 - classifier_accuracy: 0.9911 - val_loss: 0.3418 - val_reconstruction_loss: 0.3039 - val_dkl_loss_loss: 0.1152 - val_classifier_loss: 0.4929 - val_classifier_accuracy: 0.9114
# Epoch 83/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1508 - reconstruction_loss: 0.3015 - dkl_loss_loss: 0.1092 - classifier_loss: 0.0209 - classifier_accuracy: 0.9927 - val_loss: 0.3086 - val_reconstruction_loss: 0.3040 - val_dkl_loss_loss: 0.1057 - val_classifier_loss: 0.4147 - val_classifier_accuracy: 0.9226
# Epoch 84/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1528 - reconstruction_loss: 0.3016 - dkl_loss_loss: 0.1109 - classifier_loss: 0.0250 - classifier_accuracy: 0.9914 - val_loss: 0.3122 - val_reconstruction_loss: 0.3035 - val_dkl_loss_loss: 0.1109 - val_classifier_loss: 0.4215 - val_classifier_accuracy: 0.9186
# Epoch 85/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1511 - reconstruction_loss: 0.3014 - dkl_loss_loss: 0.1088 - classifier_loss: 0.0220 - classifier_accuracy: 0.9927 - val_loss: 0.3109 - val_reconstruction_loss: 0.3029 - val_dkl_loss_loss: 0.1115 - val_classifier_loss: 0.4185 - val_classifier_accuracy: 0.9208
# Epoch 86/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1490 - reconstruction_loss: 0.3013 - dkl_loss_loss: 0.1087 - classifier_loss: 0.0169 - classifier_accuracy: 0.9942 - val_loss: 0.3545 - val_reconstruction_loss: 0.3036 - val_dkl_loss_loss: 0.1115 - val_classifier_loss: 0.5270 - val_classifier_accuracy: 0.9084
# Epoch 87/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1513 - reconstruction_loss: 0.3015 - dkl_loss_loss: 0.1086 - classifier_loss: 0.0225 - classifier_accuracy: 0.9919 - val_loss: 0.3243 - val_reconstruction_loss: 0.3036 - val_dkl_loss_loss: 0.1137 - val_classifier_loss: 0.4502 - val_classifier_accuracy: 0.9200
# Epoch 88/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1524 - reconstruction_loss: 0.3013 - dkl_loss_loss: 0.1109 - classifier_loss: 0.0242 - classifier_accuracy: 0.9923 - val_loss: 0.3448 - val_reconstruction_loss: 0.3043 - val_dkl_loss_loss: 0.1143 - val_classifier_loss: 0.5006 - val_classifier_accuracy: 0.9140
# Epoch 89/150
# 860/860 [==============================] - 12s 13ms/step - loss: 0.1495 - reconstruction_loss: 0.3013 - dkl_loss_loss: 0.1089 - classifier_loss: 0.0180 - classifier_accuracy: 0.9939 - val_loss: 0.3244 - val_reconstruction_loss: 0.3043 - val_dkl_loss_loss: 0.1062 - val_classifier_loss: 0.4536 - val_classifier_accuracy: 0.9170
# Epoch 90/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1531 - reconstruction_loss: 0.3014 - dkl_loss_loss: 0.1114 - classifier_loss: 0.0257 - classifier_accuracy: 0.9912 - val_loss: 0.3134 - val_reconstruction_loss: 0.3033 - val_dkl_loss_loss: 0.1106 - val_classifier_loss: 0.4250 - val_classifier_accuracy: 0.9190
# Epoch 91/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1494 - reconstruction_loss: 0.3014 - dkl_loss_loss: 0.1076 - classifier_loss: 0.0183 - classifier_accuracy: 0.9937 - val_loss: 0.3168 - val_reconstruction_loss: 0.3046 - val_dkl_loss_loss: 0.1043 - val_classifier_loss: 0.4353 - val_classifier_accuracy: 0.9138
# Epoch 92/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1489 - reconstruction_loss: 0.3012 - dkl_loss_loss: 0.1064 - classifier_loss: 0.0179 - classifier_accuracy: 0.9941 - val_loss: 0.3360 - val_reconstruction_loss: 0.3054 - val_dkl_loss_loss: 0.1020 - val_classifier_loss: 0.4837 - val_classifier_accuracy: 0.9104
# Epoch 93/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1521 - reconstruction_loss: 0.3013 - dkl_loss_loss: 0.1089 - classifier_loss: 0.0245 - classifier_accuracy: 0.9917 - val_loss: 0.3144 - val_reconstruction_loss: 0.3039 - val_dkl_loss_loss: 0.1086 - val_classifier_loss: 0.4278 - val_classifier_accuracy: 0.9172
# Epoch 94/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1464 - reconstruction_loss: 0.3011 - dkl_loss_loss: 0.1057 - classifier_loss: 0.0120 - classifier_accuracy: 0.9960 - val_loss: 0.3048 - val_reconstruction_loss: 0.3048 - val_dkl_loss_loss: 0.0972 - val_classifier_loss: 0.4085 - val_classifier_accuracy: 0.9192
# Epoch 95/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1546 - reconstruction_loss: 0.3014 - dkl_loss_loss: 0.1118 - classifier_loss: 0.0292 - classifier_accuracy: 0.9903 - val_loss: 0.3114 - val_reconstruction_loss: 0.3036 - val_dkl_loss_loss: 0.1038 - val_classifier_loss: 0.4231 - val_classifier_accuracy: 0.9194
# Epoch 96/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1472 - reconstruction_loss: 0.3009 - dkl_loss_loss: 0.1067 - classifier_loss: 0.0139 - classifier_accuracy: 0.9953 - val_loss: 0.3239 - val_reconstruction_loss: 0.3032 - val_dkl_loss_loss: 0.1090 - val_classifier_loss: 0.4519 - val_classifier_accuracy: 0.9176
# Epoch 97/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1522 - reconstruction_loss: 0.3012 - dkl_loss_loss: 0.1097 - classifier_loss: 0.0245 - classifier_accuracy: 0.9918 - val_loss: 0.3186 - val_reconstruction_loss: 0.3040 - val_dkl_loss_loss: 0.1083 - val_classifier_loss: 0.4383 - val_classifier_accuracy: 0.9156
# Epoch 98/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1493 - reconstruction_loss: 0.3010 - dkl_loss_loss: 0.1081 - classifier_loss: 0.0182 - classifier_accuracy: 0.9937 - val_loss: 0.3370 - val_reconstruction_loss: 0.3041 - val_dkl_loss_loss: 0.1047 - val_classifier_loss: 0.4861 - val_classifier_accuracy: 0.9142
# Epoch 99/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1487 - reconstruction_loss: 0.3011 - dkl_loss_loss: 0.1076 - classifier_loss: 0.0168 - classifier_accuracy: 0.9943 - val_loss: 0.3255 - val_reconstruction_loss: 0.3031 - val_dkl_loss_loss: 0.1072 - val_classifier_loss: 0.4571 - val_classifier_accuracy: 0.9174
# Epoch 100/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1491 - reconstruction_loss: 0.3010 - dkl_loss_loss: 0.1068 - classifier_loss: 0.0184 - classifier_accuracy: 0.9939 - val_loss: 0.3098 - val_reconstruction_loss: 0.3031 - val_dkl_loss_loss: 0.1079 - val_classifier_loss: 0.4174 - val_classifier_accuracy: 0.9196
# Epoch 101/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1502 - reconstruction_loss: 0.3010 - dkl_loss_loss: 0.1082 - classifier_loss: 0.0204 - classifier_accuracy: 0.9929 - val_loss: 0.3294 - val_reconstruction_loss: 0.3022 - val_dkl_loss_loss: 0.1144 - val_classifier_loss: 0.4640 - val_classifier_accuracy: 0.9152
# Epoch 102/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1490 - reconstruction_loss: 0.3010 - dkl_loss_loss: 0.1071 - classifier_loss: 0.0181 - classifier_accuracy: 0.9939 - val_loss: 0.3393 - val_reconstruction_loss: 0.3032 - val_dkl_loss_loss: 0.1076 - val_classifier_loss: 0.4913 - val_classifier_accuracy: 0.9098
# Epoch 103/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1481 - reconstruction_loss: 0.3008 - dkl_loss_loss: 0.1067 - classifier_loss: 0.0161 - classifier_accuracy: 0.9947 - val_loss: 0.3267 - val_reconstruction_loss: 0.3032 - val_dkl_loss_loss: 0.1027 - val_classifier_loss: 0.4623 - val_classifier_accuracy: 0.9130
# Epoch 104/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1501 - reconstruction_loss: 0.3008 - dkl_loss_loss: 0.1084 - classifier_loss: 0.0202 - classifier_accuracy: 0.9933 - val_loss: 0.3289 - val_reconstruction_loss: 0.3035 - val_dkl_loss_loss: 0.1065 - val_classifier_loss: 0.4654 - val_classifier_accuracy: 0.9196
# Epoch 105/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1491 - reconstruction_loss: 0.3008 - dkl_loss_loss: 0.1068 - classifier_loss: 0.0184 - classifier_accuracy: 0.9938 - val_loss: 0.3422 - val_reconstruction_loss: 0.3033 - val_dkl_loss_loss: 0.1113 - val_classifier_loss: 0.4965 - val_classifier_accuracy: 0.9120
# Epoch 106/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1495 - reconstruction_loss: 0.3008 - dkl_loss_loss: 0.1087 - classifier_loss: 0.0187 - classifier_accuracy: 0.9932 - val_loss: 0.3448 - val_reconstruction_loss: 0.3041 - val_dkl_loss_loss: 0.1099 - val_classifier_loss: 0.5030 - val_classifier_accuracy: 0.9182
# Epoch 107/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1484 - reconstruction_loss: 0.3008 - dkl_loss_loss: 0.1068 - classifier_loss: 0.0168 - classifier_accuracy: 0.9946 - val_loss: 0.3169 - val_reconstruction_loss: 0.3040 - val_dkl_loss_loss: 0.1020 - val_classifier_loss: 0.4374 - val_classifier_accuracy: 0.9192
# Epoch 108/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1494 - reconstruction_loss: 0.3009 - dkl_loss_loss: 0.1074 - classifier_loss: 0.0188 - classifier_accuracy: 0.9939 - val_loss: 0.3301 - val_reconstruction_loss: 0.3042 - val_dkl_loss_loss: 0.1098 - val_classifier_loss: 0.4661 - val_classifier_accuracy: 0.9180
# Epoch 109/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1495 - reconstruction_loss: 0.3010 - dkl_loss_loss: 0.1083 - classifier_loss: 0.0185 - classifier_accuracy: 0.9938 - val_loss: 0.3419 - val_reconstruction_loss: 0.3034 - val_dkl_loss_loss: 0.1148 - val_classifier_loss: 0.4939 - val_classifier_accuracy: 0.9160
# Epoch 110/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1495 - reconstruction_loss: 0.3009 - dkl_loss_loss: 0.1083 - classifier_loss: 0.0186 - classifier_accuracy: 0.9935 - val_loss: 0.3262 - val_reconstruction_loss: 0.3032 - val_dkl_loss_loss: 0.1021 - val_classifier_loss: 0.4612 - val_classifier_accuracy: 0.9160
# Epoch 111/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1472 - reconstruction_loss: 0.3006 - dkl_loss_loss: 0.1061 - classifier_loss: 0.0142 - classifier_accuracy: 0.9953 - val_loss: 0.3162 - val_reconstruction_loss: 0.3024 - val_dkl_loss_loss: 0.1028 - val_classifier_loss: 0.4367 - val_classifier_accuracy: 0.9184
# Epoch 112/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1507 - reconstruction_loss: 0.3008 - dkl_loss_loss: 0.1072 - classifier_loss: 0.0223 - classifier_accuracy: 0.9923 - val_loss: 0.3314 - val_reconstruction_loss: 0.3045 - val_dkl_loss_loss: 0.1039 - val_classifier_loss: 0.4719 - val_classifier_accuracy: 0.9152
# Epoch 113/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1463 - reconstruction_loss: 0.3006 - dkl_loss_loss: 0.1049 - classifier_loss: 0.0128 - classifier_accuracy: 0.9955 - val_loss: 0.3305 - val_reconstruction_loss: 0.3034 - val_dkl_loss_loss: 0.1013 - val_classifier_loss: 0.4722 - val_classifier_accuracy: 0.9146
# Epoch 114/150
# 860/860 [==============================] - 12s 14ms/step - loss: 0.1495 - reconstruction_loss: 0.3007 - dkl_loss_loss: 0.1079 - classifier_loss: 0.0191 - classifier_accuracy: 0.9934 - val_loss: 0.3506 - val_reconstruction_loss: 0.3035 - val_dkl_loss_loss: 0.1146 - val_classifier_loss: 0.5157 - val_classifier_accuracy: 0.9136
# Epoch 115/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1486 - reconstruction_loss: 0.3006 - dkl_loss_loss: 0.1069 - classifier_loss: 0.0174 - classifier_accuracy: 0.9940 - val_loss: 0.3204 - val_reconstruction_loss: 0.3028 - val_dkl_loss_loss: 0.1068 - val_classifier_loss: 0.4447 - val_classifier_accuracy: 0.9210
# Epoch 116/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1483 - reconstruction_loss: 0.3007 - dkl_loss_loss: 0.1058 - classifier_loss: 0.0172 - classifier_accuracy: 0.9944 - val_loss: 0.3420 - val_reconstruction_loss: 0.3030 - val_dkl_loss_loss: 0.1056 - val_classifier_loss: 0.4993 - val_classifier_accuracy: 0.9098
# Epoch 117/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1484 - reconstruction_loss: 0.3006 - dkl_loss_loss: 0.1052 - classifier_loss: 0.0179 - classifier_accuracy: 0.9942 - val_loss: 0.3212 - val_reconstruction_loss: 0.3030 - val_dkl_loss_loss: 0.1054 - val_classifier_loss: 0.4474 - val_classifier_accuracy: 0.9146
# Epoch 118/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1481 - reconstruction_loss: 0.3005 - dkl_loss_loss: 0.1067 - classifier_loss: 0.0165 - classifier_accuracy: 0.9945 - val_loss: 0.3258 - val_reconstruction_loss: 0.3035 - val_dkl_loss_loss: 0.0984 - val_classifier_loss: 0.4618 - val_classifier_accuracy: 0.9160
# Epoch 119/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1486 - reconstruction_loss: 0.3007 - dkl_loss_loss: 0.1065 - classifier_loss: 0.0176 - classifier_accuracy: 0.9937 - val_loss: 0.3383 - val_reconstruction_loss: 0.3040 - val_dkl_loss_loss: 0.1037 - val_classifier_loss: 0.4899 - val_classifier_accuracy: 0.9116
# Epoch 120/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1470 - reconstruction_loss: 0.3005 - dkl_loss_loss: 0.1050 - classifier_loss: 0.0145 - classifier_accuracy: 0.9955 - val_loss: 0.3270 - val_reconstruction_loss: 0.3016 - val_dkl_loss_loss: 0.1061 - val_classifier_loss: 0.4628 - val_classifier_accuracy: 0.9152
# Epoch 121/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1483 - reconstruction_loss: 0.3004 - dkl_loss_loss: 0.1054 - classifier_loss: 0.0177 - classifier_accuracy: 0.9940 - val_loss: 0.3747 - val_reconstruction_loss: 0.3040 - val_dkl_loss_loss: 0.1115 - val_classifier_loss: 0.5771 - val_classifier_accuracy: 0.9048
# Epoch 122/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1487 - reconstruction_loss: 0.3002 - dkl_loss_loss: 0.1085 - classifier_loss: 0.0174 - classifier_accuracy: 0.9939 - val_loss: 0.3399 - val_reconstruction_loss: 0.3021 - val_dkl_loss_loss: 0.1106 - val_classifier_loss: 0.4923 - val_classifier_accuracy: 0.9172
# Epoch 123/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1488 - reconstruction_loss: 0.3005 - dkl_loss_loss: 0.1071 - classifier_loss: 0.0179 - classifier_accuracy: 0.9936 - val_loss: 0.3442 - val_reconstruction_loss: 0.3030 - val_dkl_loss_loss: 0.1071 - val_classifier_loss: 0.5041 - val_classifier_accuracy: 0.9096
# Epoch 124/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1493 - reconstruction_loss: 0.3004 - dkl_loss_loss: 0.1064 - classifier_loss: 0.0195 - classifier_accuracy: 0.9935 - val_loss: 0.3283 - val_reconstruction_loss: 0.3017 - val_dkl_loss_loss: 0.1119 - val_classifier_loss: 0.4631 - val_classifier_accuracy: 0.9190
# Epoch 125/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1455 - reconstruction_loss: 0.3003 - dkl_loss_loss: 0.1040 - classifier_loss: 0.0113 - classifier_accuracy: 0.9963 - val_loss: 0.3203 - val_reconstruction_loss: 0.3033 - val_dkl_loss_loss: 0.1013 - val_classifier_loss: 0.4467 - val_classifier_accuracy: 0.9250
# Epoch 126/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1495 - reconstruction_loss: 0.3004 - dkl_loss_loss: 0.1065 - classifier_loss: 0.0202 - classifier_accuracy: 0.9931 - val_loss: 0.3476 - val_reconstruction_loss: 0.3045 - val_dkl_loss_loss: 0.1104 - val_classifier_loss: 0.5092 - val_classifier_accuracy: 0.9158
# Epoch 127/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1472 - reconstruction_loss: 0.3001 - dkl_loss_loss: 0.1070 - classifier_loss: 0.0144 - classifier_accuracy: 0.9954 - val_loss: 0.3228 - val_reconstruction_loss: 0.3018 - val_dkl_loss_loss: 0.1042 - val_classifier_loss: 0.4531 - val_classifier_accuracy: 0.9202
# Epoch 128/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1445 - reconstruction_loss: 0.3002 - dkl_loss_loss: 0.1027 - classifier_loss: 0.0097 - classifier_accuracy: 0.9967 - val_loss: 0.3180 - val_reconstruction_loss: 0.3024 - val_dkl_loss_loss: 0.1007 - val_classifier_loss: 0.4422 - val_classifier_accuracy: 0.9212
# Epoch 129/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1489 - reconstruction_loss: 0.3003 - dkl_loss_loss: 0.1064 - classifier_loss: 0.0188 - classifier_accuracy: 0.9938 - val_loss: 0.3284 - val_reconstruction_loss: 0.3027 - val_dkl_loss_loss: 0.1106 - val_classifier_loss: 0.4631 - val_classifier_accuracy: 0.9190
# Epoch 130/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1496 - reconstruction_loss: 0.3003 - dkl_loss_loss: 0.1079 - classifier_loss: 0.0196 - classifier_accuracy: 0.9938 - val_loss: 0.3224 - val_reconstruction_loss: 0.3035 - val_dkl_loss_loss: 0.1055 - val_classifier_loss: 0.4497 - val_classifier_accuracy: 0.9158
# Epoch 131/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1461 - reconstruction_loss: 0.3001 - dkl_loss_loss: 0.1056 - classifier_loss: 0.0123 - classifier_accuracy: 0.9959 - val_loss: 0.3384 - val_reconstruction_loss: 0.3021 - val_dkl_loss_loss: 0.1069 - val_classifier_loss: 0.4905 - val_classifier_accuracy: 0.9150
# Epoch 132/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1493 - reconstruction_loss: 0.3003 - dkl_loss_loss: 0.1087 - classifier_loss: 0.0187 - classifier_accuracy: 0.9936 - val_loss: 0.3413 - val_reconstruction_loss: 0.3037 - val_dkl_loss_loss: 0.1024 - val_classifier_loss: 0.4982 - val_classifier_accuracy: 0.9104
# Epoch 133/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1469 - reconstruction_loss: 0.3001 - dkl_loss_loss: 0.1047 - classifier_loss: 0.0148 - classifier_accuracy: 0.9951 - val_loss: 0.3335 - val_reconstruction_loss: 0.3031 - val_dkl_loss_loss: 0.1043 - val_classifier_loss: 0.4785 - val_classifier_accuracy: 0.9152
# Epoch 134/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1487 - reconstruction_loss: 0.3002 - dkl_loss_loss: 0.1069 - classifier_loss: 0.0180 - classifier_accuracy: 0.9934 - val_loss: 0.3396 - val_reconstruction_loss: 0.3027 - val_dkl_loss_loss: 0.1080 - val_classifier_loss: 0.4924 - val_classifier_accuracy: 0.9164
# Epoch 135/150
# 860/860 [==============================] - 11s 12ms/step - loss: 0.1478 - reconstruction_loss: 0.3002 - dkl_loss_loss: 0.1049 - classifier_loss: 0.0169 - classifier_accuracy: 0.9947 - val_loss: 0.3316 - val_reconstruction_loss: 0.3023 - val_dkl_loss_loss: 0.1055 - val_classifier_loss: 0.4740 - val_classifier_accuracy: 0.9216
# Epoch 136/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1452 - reconstruction_loss: 0.3000 - dkl_loss_loss: 0.1035 - classifier_loss: 0.0113 - classifier_accuracy: 0.9963 - val_loss: 0.3475 - val_reconstruction_loss: 0.3034 - val_dkl_loss_loss: 0.1068 - val_classifier_loss: 0.5121 - val_classifier_accuracy: 0.9106
# Epoch 137/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1504 - reconstruction_loss: 0.3003 - dkl_loss_loss: 0.1069 - classifier_loss: 0.0223 - classifier_accuracy: 0.9929 - val_loss: 0.3482 - val_reconstruction_loss: 0.3049 - val_dkl_loss_loss: 0.1001 - val_classifier_loss: 0.5154 - val_classifier_accuracy: 0.9122
# Epoch 138/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1447 - reconstruction_loss: 0.2999 - dkl_loss_loss: 0.1031 - classifier_loss: 0.0104 - classifier_accuracy: 0.9965 - val_loss: 0.3368 - val_reconstruction_loss: 0.3037 - val_dkl_loss_loss: 0.0969 - val_classifier_loss: 0.4898 - val_classifier_accuracy: 0.9138
# Epoch 139/150
# 860/860 [==============================] - 12s 14ms/step - loss: 0.1493 - reconstruction_loss: 0.3006 - dkl_loss_loss: 0.1081 - classifier_loss: 0.0187 - classifier_accuracy: 0.9934 - val_loss: 0.3385 - val_reconstruction_loss: 0.3025 - val_dkl_loss_loss: 0.1052 - val_classifier_loss: 0.4912 - val_classifier_accuracy: 0.9164
# Epoch 140/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1443 - reconstruction_loss: 0.3001 - dkl_loss_loss: 0.1021 - classifier_loss: 0.0097 - classifier_accuracy: 0.9970 - val_loss: 0.3321 - val_reconstruction_loss: 0.3030 - val_dkl_loss_loss: 0.1112 - val_classifier_loss: 0.4716 - val_classifier_accuracy: 0.9184
# Epoch 141/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1491 - reconstruction_loss: 0.3000 - dkl_loss_loss: 0.1079 - classifier_loss: 0.0189 - classifier_accuracy: 0.9935 - val_loss: 0.3334 - val_reconstruction_loss: 0.3025 - val_dkl_loss_loss: 0.1006 - val_classifier_loss: 0.4807 - val_classifier_accuracy: 0.9162
# Epoch 142/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1463 - reconstruction_loss: 0.2999 - dkl_loss_loss: 0.1045 - classifier_loss: 0.0137 - classifier_accuracy: 0.9956 - val_loss: 0.3539 - val_reconstruction_loss: 0.3045 - val_dkl_loss_loss: 0.1056 - val_classifier_loss: 0.5275 - val_classifier_accuracy: 0.9138
# Epoch 143/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1480 - reconstruction_loss: 0.3002 - dkl_loss_loss: 0.1057 - classifier_loss: 0.0170 - classifier_accuracy: 0.9945 - val_loss: 0.3275 - val_reconstruction_loss: 0.3025 - val_dkl_loss_loss: 0.1042 - val_classifier_loss: 0.4640 - val_classifier_accuracy: 0.9188
# Epoch 144/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1450 - reconstruction_loss: 0.2999 - dkl_loss_loss: 0.1022 - classifier_loss: 0.0114 - classifier_accuracy: 0.9963 - val_loss: 0.3438 - val_reconstruction_loss: 0.3021 - val_dkl_loss_loss: 0.1094 - val_classifier_loss: 0.5026 - val_classifier_accuracy: 0.9166
# Epoch 145/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1471 - reconstruction_loss: 0.2999 - dkl_loss_loss: 0.1062 - classifier_loss: 0.0149 - classifier_accuracy: 0.9950 - val_loss: 0.3421 - val_reconstruction_loss: 0.3026 - val_dkl_loss_loss: 0.1050 - val_classifier_loss: 0.5001 - val_classifier_accuracy: 0.9162
# Epoch 146/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1489 - reconstruction_loss: 0.3002 - dkl_loss_loss: 0.1066 - classifier_loss: 0.0188 - classifier_accuracy: 0.9940 - val_loss: 0.3365 - val_reconstruction_loss: 0.3015 - val_dkl_loss_loss: 0.1060 - val_classifier_loss: 0.4868 - val_classifier_accuracy: 0.9202
# Epoch 147/150
# 860/860 [==============================] - 10s 12ms/step - loss: 0.1437 - reconstruction_loss: 0.2999 - dkl_loss_loss: 0.1000 - classifier_loss: 0.0094 - classifier_accuracy: 0.9971 - val_loss: 0.3506 - val_reconstruction_loss: 0.3027 - val_dkl_loss_loss: 0.1034 - val_classifier_loss: 0.5222 - val_classifier_accuracy: 0.9186
# Epoch 148/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1503 - reconstruction_loss: 0.3001 - dkl_loss_loss: 0.1085 - classifier_loss: 0.0214 - classifier_accuracy: 0.9927 - val_loss: 0.3393 - val_reconstruction_loss: 0.3013 - val_dkl_loss_loss: 0.1060 - val_classifier_loss: 0.4940 - val_classifier_accuracy: 0.9194
# Epoch 149/150
# 860/860 [==============================] - 11s 13ms/step - loss: 0.1443 - reconstruction_loss: 0.2998 - dkl_loss_loss: 0.1023 - classifier_loss: 0.0099 - classifier_accuracy: 0.9969 - val_loss: 0.3421 - val_reconstruction_loss: 0.3018 - val_dkl_loss_loss: 0.1051 - val_classifier_loss: 0.5009 - val_classifier_accuracy: 0.9144
# Epoch 150/150
# 860/860 [==============================] - 12s 13ms/step - loss: 0.1483 - reconstruction_loss: 0.3001 - dkl_loss_loss: 0.1065 - classifier_loss: 0.0175 - classifier_accuracy: 0.9939 - val_loss: 0.3343 - val_reconstruction_loss: 0.3031 - val_dkl_loss_loss: 0.1023 - val_classifier_loss: 0.4815 - val_classifier_accuracy: 0.9138

# %% [markdown]
# ##Evaluación del modelo

# %%
# Crear el nuevo modelo del decodificador
decoder = tf.keras.Model(inputs=model.get_layer('sampling').output, outputs=model.get_layer('reconstruction').output)

# Ahora puedes usar el decodificador para generar nuevas imágenes
# Crear el nuevo modelo del decodificador
encoder = tf.keras.Model(inputs=model.get_layer('conv1').input, outputs=model.get_layer('sampling').output)

# Ahora puedes usar el decodificador para generar nuevas imágenes

# %%
show_reconstructions(model)
# Out:
# 1/1 [==============================] - 1s 560ms/step

# %%
tf.random.set_seed(0)
codings = tf.random.normal(shape=[12, latent_dim])
images = decoder(codings).numpy()
plot_multiple_images(images, 4)
save_fig("vae_generated_images_plot", tight_layout=False)
# Out:
# Saving figure vae_generated_images_plot

# %%
tf.random.set_seed(10)
np.random.seed(0)
codings_grid = tf.reshape(codings, [1, 3, 4, latent_dim])
larger_grid = tf.image.resize(codings_grid, size=[5, 7])
interpolated_codings = tf.reshape(larger_grid, [-1, latent_dim])
images = decoder(interpolated_codings).numpy()
plt.figure(figsize=(7, 5))
for index, image in enumerate(images):
    plt.subplot(5, 7, index + 1)
    if index%7%2==0 and index//7%2==0:
        plt.gca().get_xaxis().set_visible(False)
        plt.gca().get_yaxis().set_visible(False)
    else:
        plt.axis("off")
    plt.imshow(image, cmap="binary")
save_fig("semantic_interpolation_plot", tight_layout=False)
# Out:
# Saving figure semantic_interpolation_plot

# %% [markdown]
# ##Curva de rendimiento

# %%
evaluar_modelo(history, model, X_test,tf.keras.utils.to_categorical(y_test))
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %% [markdown]
# ##Matriz de confusión

# %%
evaluate_classifier(X_test, tf.keras.utils.to_categorical(y_test), model)
# Out:
# 313/313 [==============================] - 2s 5ms/step
# Precision: 0.9158
# Recall: 0.9118
# F2-score: 0.9119
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.85      1000
#            1       0.99      0.99      0.99      1000
#            2       0.85      0.87      0.86      1000
#            3       0.93      0.90      0.91      1000
#            4       0.90      0.82      0.86      1000
#            5       0.98      0.99      0.99      1000
#            6       0.70      0.83      0.76      1000
#            7       0.97      0.97      0.97      1000
#            8       0.98      0.98      0.98      1000
#            9       0.98      0.97      0.97      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.92      0.91      0.91     10000
# weighted avg       0.92      0.91      0.91     10000

# %% [markdown]
# ## Espacio latente visto con TSNE

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

encoder = tf.keras.Model(inputs=model.get_layer('conv1').input, outputs=model.get_layer('classifier').output)

codings = encoder.predict(X_test)

# Paso 2: Aplicar t-SNE
# Reducimos a 2D para visualización
tsne = TSNE(n_components=2, random_state=42)
codings_2d = tsne.fit_transform(codings)

# Paso 3: Graficar con colores según las clases
plt.figure(figsize=(10, 8))
scatter = plt.scatter(codings_2d[:, 0], codings_2d[:, 1], c=y_test, cmap='tab10', alpha=0.7)
plt.colorbar(scatter, ticks=range(10))
plt.title("t-SNE del Espacio Latente")
plt.xlabel("Componente t-SNE 1")
plt.ylabel("Componente t-SNE 2")
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ## GradCam++

# %%
layers = ['conv1']
generate_and_plot_cam_for_output(model, X_test,y_test, layers, output_name='classifier', class_mode=True)
# Out:
# Capa: conv1

# %%
layers = ['conv2']
generate_and_plot_cam_for_output(model, X_test, y_test, layers, output_name='classifier', class_mode=True)
# Out:
# Capa: conv2

# %%
layers = ['conv3']
generate_and_plot_cam_for_output(model, X_test, y_test, layers, output_name='classifier', class_mode=True)
# Out:
# Capa: conv3

# %%
layers = ['Capa_h']
generate_and_plot_cam_for_output(model, X_test, y_test, layers, output_name='classifier', class_mode=True)
# Out:
# Capa: Capa_h
